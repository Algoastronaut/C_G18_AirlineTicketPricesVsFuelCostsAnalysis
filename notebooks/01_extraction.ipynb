# %%
import pandas as pd

# %%
df_ticket = pd.read_csv("../data/raw/airline_ticket_prices.csv")
df_fuel = pd.read_csv("../data/raw/oil_jet_fuel_prices.csv")
df_surcharge = pd.read_csv("../data/raw/fuel_surcharges.csv")
df_conflict = pd.read_csv("../data/raw/conflict_oil_events.csv")
df_financial = pd.read_csv("../data/raw/airline_financial_impact.csv")
df_route = pd.read_csv("../data/raw/route_cost_impact.csv")

# %%
print(df_ticket.head())
print(df_fuel.head())
# Out:
#      month         conflict_phase airline iata_code country region  \
# 0  2019-01  Pre-Pandemic Baseline     ANA        NH   Japan   Asia
# 1  2019-02  Pre-Pandemic Baseline     ANA        NH   Japan   Asia
# 2  2019-03  Pre-Pandemic Baseline     ANA        NH   Japan   Asia
# 3  2019-04  Pre-Pandemic Baseline     ANA        NH   Japan   Asia
# 4  2019-05  Pre-Pandemic Baseline     ANA        NH   Japan   Asia
#
#    airline_type route_class  avg_route_km  base_fare_usd  fuel_surcharge_usd  \
# 0  Flag Carrier   Long-Haul          8500        1179.91              106.53
# 1  Flag Carrier   Long-Haul          8500        1176.08               63.96
# 2  Flag Carrier   Long-Haul          8500        1133.88              117.51
# 3  Flag Carrier   Long-Haul          8500        1237.95               58.99
# 4  Flag Carrier   Long-Haul          8500        1270.08               87.06
#
#    taxes_fees_usd  total_fare_usd  brent_crude_usd  jet_fuel_usd_barrel  \
# ...

# %%
df_ticket.isnull().sum()
# Out:
# month                      0
# conflict_phase             0
# airline                    0
# iata_code                  0
# country                    0
# region                     0
# airline_type               0
# route_class                0
# avg_route_km               0
# base_fare_usd              0
# fuel_surcharge_usd         0
# taxes_fees_usd             0
# total_fare_usd             0
# brent_crude_usd            0
# jet_fuel_usd_barrel        0
# load_factor_pct            0
# fuel_cost_pct_opex         0
# yoy_price_change_pct    1980
# dtype: int64
